# %% [markdown]
# It is recomended to make a new python virtual environment for this workshop, to avoid conflicting versions.
# This is generally best practice when starting any new project!
#
# #### Creating a new virtual environment (VSCode)
# ##### Step 1
# Press *select kernel* in the upper right-hand corner
#
# ![image](media/new_environment1.PNG)
#
# ##### Step 2
# Press *create python environment* in the upper middle of the screen
#
# ![image](media/new_environment2.PNG)
#
#
# ##### Step 3
# Press *venv* in the upper middle of the screen
#
# ![image](media/new_environment3.PNG)
#
# ##### Step 4
# Wait! Then you are done

# %%
############## This will install all the needed packages for this tutorial

# the default `georinex` package is slow at reading RINEX v3 obs so use my version
# note: this may take several minutes
# %pip install git+https://github.com/breid-phys/georinex.git

# this will also install numpy, pandas, xarray, and a few others

# %%
# install matplotlib for plotting
# %pip install matplotlib

# %%
# install bottleneck for xarray functionality
# %pip install bottleneck
# Out:
# ...
#   Using cached bottleneck-1.6.0-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# ...
# Using cached bottleneck-1.6.0-cp311-cp311-win_amd64.whl (113 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# install scipy
# %pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    --- ------------------------------------ 3.1/36.6 MB 18.5 MB/s eta 0:00:02
#    -------- ------------------------------- 7.3/36.6 MB 18.9 MB/s eta 0:00:02
#    ------------- -------------------------- 12.6/36.6 MB 20.8 MB/s eta 0:00:02
#    ------------------- -------------------- 18.1/36.6 MB 22.4 MB/s eta 0:00:01
#    -------------------------- ------------- 24.4/36.6 MB 23.4 MB/s eta 0:00:01
#    ------------------------------- -------- 28.8/36.6 MB 23.2 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/36.6 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 21.8 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
